# %%
# ADVANCED DATABASES - LAB #6
# Filtering data in SQLAlchemy

# %%
from sqlalchemy import create_engine

# database_type://user:password@database_url:port/database_name
db_string = 'postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb'

# create_engine is just interface to connection database with program
db = create_engine(db_string)

# %%
# We can use a script to initialize mapper operation
from sqlalchemy import create_engine, MetaData, Table

metadata = MetaData()

dic_table = {}
for table_name in db.table_names():
    dic_table[table_name] = Table(table_name, metadata , autoload=True, autoload_with=db)

# %%
print(repr(dic_table['category']))
# Out:
# Table('category', MetaData(bind=None), Column('category_id', INTEGER(), table=<category>, primary_key=True, nullable=False, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x7f57b1056710>, for_update=False)), Column('name', VARCHAR(length=25), table=<category>, nullable=False), Column('last_update', TIMESTAMP(), table=<category>, nullable=False, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x7f57b03e4850>, for_update=False)), schema=None)

# %%
# EXERCISE 1
# How many categories of films we have in the rental?

from sqlalchemy import select

mapper_stmt1 = "SELECT count(category.name) FROM category"
result1 = db.execute(mapper_stmt1).fetchall()

# %%
print(result1)
# 1 result
# Out:
# [(16,)]

# %%
# EXERCISE 2
# Display list of categories in alphabetic order.

mapper_stmt2 = select([dic_table['category'].columns.name]).order_by(dic_table['category'].columns.name) 
result2 = db.execute(mapper_stmt2).fetchall()

# %%
print(result2)
# 16 results
# Out:
# [('Action',), ('Animation',), ('Children',), ('Classics',), ('Comedy',), ('Documentary',), ('Drama',), ('Family',), ('Foreign',), ('Games',), ('Horror',), ('Music',), ('New',), ('Sci-Fi',), ('Sports',), ('Travel',)]

# %%
# EXERCISE 3
# Find the oldest and youngest film in rental.


mapper_stmt3 = " SELECT title, year, date FROM \
                 ( \
                     SELECT film.title AS title, film.release_year AS year, rental.return_date AS date FROM film \
                         INNER JOIN inventory ON film.film_id = inventory.film_id \
                         INNER JOIN rental ON inventory.inventory_id = rental.inventory_id \
                     GROUP BY title, year, date) \
                AS temp_table \
                WHERE year = (SELECT MAX(film.release_year) FROM film) OR \
                      year = (SELECT MIN(film.release_year) FROM film) AND \
                      date IS NULL "

result3 = db.execute(mapper_stmt3).fetchall()

# %%
for i in result3:
    print(i)

# 16030 results
# Out:
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 5, 31, 8, 1, 28))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 6, 6, 0, 36, 7))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 6, 20, 1, 41, 51))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 6, 23, 17, 45))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 6, 28, 3, 42, 26))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 7, 9, 0, 4, 6))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 7, 11, 6, 25, 31))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 7, 11, 21, 29, 15))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 7, 16, 13, 3, 31))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 1, 4, 8, 11))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 3, 0, 2, 19))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 3, 23, 59, 7))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 5, 5, 30, 38))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 6, 2, 9, 34))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 6, 16, 59, 29))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 11, 21, 35, 10))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 22, 22, 1, 16))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 23, 21, 9, 42))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 25, 18, 58, 37))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 27, 2, 18, 8))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 30, 20, 8, 1))
# ('Academy Dinosaur', 2006, datetime.datetime(2005, 8, 30, 22, 26, 43))
# ('Academy Dinosaur', 2006, None)
# ('Ace Goldfinger', 2006, datetime.datetime(2005, 7, 8, 21, 55, 51))
# ('Ace Goldfinger', 2006, datetime.datetime(2005, 8, 4, 5, 36, 47))
# ('Ace Goldfinger', 2006, datetime.datetime(2005, 8, 5, 5, 12, 47))
# ('Ace Goldfinger', 2006, datetime.datetime(2005, 8, 9, 2, 13, 17))
# ('Ace Goldfinger', 2006, datetime.datetime(2005, 8, 24, 5, 3, 2))
# ('Ace Goldfinger', 2006, datetime.datetime(2005, 8, 30, 17, 1, 5))
# ('Ace Goldfinger', 2006, None)
# ('Adaptation Holes', 2006, datetime.datetime(2005, 6, 2, 1, 53, 7))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 6, 16, 15, 47, 28))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 7, 11, 21, 50, 43))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 7, 12, 21, 35, 51))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 7, 29, 20, 33, 19))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 7, 29, 23, 4, 29))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 8, 3, 21, 14, 10))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 8, 10, 12, 12, 4))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 8, 18, 11, 21, 38))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 8, 24, 15, 52, 15))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 8, 25, 4, 50, 21))
# ('Adaptation Holes', 2006, datetime.datetime(2005, 8, 26, 10, 17, 39))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 6, 2, 2, 43, 36))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 6, 6, 2, 30, 2))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 6, 19, 15, 37, 31))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 6, 22, 23, 52, 14))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 7, 22, 15, 29))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 12, 14, 44, 39))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 15, 18, 29, 1))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 15, 19, 34, 17))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 16, 4, 56, 41))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 19, 15, 56, 18))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 31, 15, 39, 28))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 7, 31, 15, 46))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 2, 8, 24, 7))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 3, 20, 0, 14))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 4, 7, 9, 29))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 8, 12, 33, 29))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 18, 4, 7, 55))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 19, 21, 58, 46))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 24, 11, 33, 18))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 25, 20, 12, 49))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 31, 0, 38, 54))
# ('Affair Prejudice', 2006, datetime.datetime(2005, 8, 31, 10, 47, 36))
# ('Affair Prejudice', 2006, None)
# ('African Egg', 2006, datetime.datetime(2005, 6, 4, 12, 45, 38))
# ('African Egg', 2006, datetime.datetime(2005, 6, 23, 11, 24, 2))
# ('African Egg', 2006, datetime.datetime(2005, 6, 26, 9, 19, 12))
# ('African Egg', 2006, datetime.datetime(2005, 7, 17, 2, 5, 43))
# ('African Egg', 2006, datetime.datetime(2005, 7, 18, 18, 27, 8))
# ('African Egg', 2006, datetime.datetime(2005, 7, 20, 9, 3, 22))
# ('African Egg', 2006, datetime.datetime(2005, 8, 3, 7, 45, 14))
# ('African Egg', 2006, datetime.datetime(2005, 8, 4, 4, 0, 44))
# ('African Egg', 2006, datetime.datetime(2005, 8, 8, 8, 30, 24))
# ('African Egg', 2006, datetime.datetime(2005, 8, 26, 6, 12, 16))
# ('African Egg', 2006, datetime.datetime(2005, 8, 27, 7, 49, 13))
# ('African Egg', 2006, None)
# ('Agent Truman', 2006, datetime.datetime(2005, 6, 1, 19, 56, 56))
# ('Agent Truman', 2006, datetime.datetime(2005, 6, 4, 15, 27, 46))
# ('Agent Truman', 2006, datetime.datetime(2005, 6, 25, 14, 12, 2))
# ('Agent Truman', 2006, datetime.datetime(2005, 6, 26, 4, 31, 4))
# ('Agent Truman', 2006, datetime.datetime(2005, 6, 29, 11, 45, 38))
# ('Agent Truman', 2006, datetime.datetime(2005, 7, 11, 9, 29, 38))
# ('Alien Center', 2006, datetime.datetime(2005, 7, 8, 21, 26, 50))
# ('Alien Center', 2006, datetime.datetime(2005, 7, 13, 12, 35, 58))
# ('Alien Center', 2006, datetime.datetime(2005, 7, 16, 1, 46, 53))
# ('Alien Center', 2006, datetime.datetime(2005, 7, 17, 4, 9, 41))
# ('Alien Center', 2006, datetime.datetime(2005, 7, 20, 7, 52, 8))
# ('Alien Center', 2006, datetime.datetime(2005, 7, 28, 4, 30, 18))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 4, 19, 6, 24))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 4, 20, 28, 1))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 5, 1, 29, 36))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 5, 18, 9, 55))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 10, 10, 23, 13))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 21, 18, 26, 48))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 22, 1, 23, 1))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 22, 4, 11, 47))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 22, 19, 28, 11))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 30, 8, 58, 9))
# ('Alien Center', 2006, datetime.datetime(2005, 8, 31, 16, 42, 22))
# ('Alley Evolution', 2006, datetime.datetime(2005, 6, 3, 11, 31, 29))
# ('Alley Evolution', 2006, datetime.datetime(2005, 6, 19, 8, 51, 46))
# ('Alley Evolution', 2006, datetime.datetime(2005, 6, 28, 1, 35, 12))
# ('Alley Evolution', 2006, datetime.datetime(2005, 7, 11, 18, 54, 36))
# ('Alley Evolution', 2006, datetime.datetime(2005, 7, 13, 18, 31, 51))
# ('Alley Evolution', 2006, datetime.datetime(2005, 7, 14, 15, 44, 57))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 3, 9, 46, 42))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 5, 15, 55, 13))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 6, 11, 24, 30))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 10, 2, 13, 46))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 21, 2, 7, 26))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 21, 8, 6, 7))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 23, 17, 50, 24))
# ('Alley Evolution', 2006, datetime.datetime(2005, 8, 28, 7, 22, 26))
# ('Alone Trip', 2006, datetime.datetime(2005, 6, 1, 7, 42, 29))
# ('Alone Trip', 2006, datetime.datetime(2005, 6, 19, 13, 49, 3))
# ('Alone Trip', 2006, datetime.datetime(2005, 6, 23, 13, 22, 32))
# ('Alone Trip', 2006, datetime.datetime(2005, 7, 12, 3, 48, 44))
# ('Alone Trip', 2006, datetime.datetime(2005, 7, 14, 11, 34, 12))
# ('Alone Trip', 2006, datetime.datetime(2005, 7, 19, 16, 43, 12))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 5, 6, 52, 26))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 6, 11, 59, 53))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 7, 5, 1, 44))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 7, 6, 0, 55))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 7, 7, 11, 47))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 8, 11, 31, 15))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 22, 16, 47, 23))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 26, 7, 20, 32))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 26, 10, 31, 5))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 26, 11, 36, 33))
# ('Alone Trip', 2006, datetime.datetime(2005, 8, 27, 4, 59, 1))
# ('Alone Trip', 2006, None)
# ('Alter Victory', 2006, datetime.datetime(2005, 5, 30, 17, 44, 58))
# ('Alter Victory', 2006, datetime.datetime(2005, 6, 2, 20, 56, 8))
# ('Alter Victory', 2006, datetime.datetime(2005, 6, 20, 9, 28, 3))
# ('Alter Victory', 2006, datetime.datetime(2005, 6, 22, 11, 17, 37))
# ('Alter Victory', 2006, datetime.datetime(2005, 6, 25, 1, 19, 54))
# ('Alter Victory', 2006, datetime.datetime(2005, 7, 12, 1, 38, 39))
# ('Alter Victory', 2006, datetime.datetime(2005, 7, 13, 12, 0, 56))
# ('Alter Victory', 2006, datetime.datetime(2005, 7, 16, 23, 30, 41))
# ('Alter Victory', 2006, datetime.datetime(2005, 7, 18, 22, 14, 43))
# ('Alter Victory', 2006, datetime.datetime(2005, 7, 21, 7, 37, 9))
# ('Alter Victory', 2006, datetime.datetime(2005, 7, 30, 22, 23, 29))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 1, 7, 0, 29))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 2, 3, 48, 25))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 2, 5, 44, 7))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 3, 18, 11, 48))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 4, 15, 21, 25))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 22, 8, 56, 6))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 23, 0, 23, 19))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 23, 3, 34, 39))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 23, 22, 33, 31))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 25, 3, 9, 51))
# ('Alter Victory', 2006, datetime.datetime(2005, 8, 28, 8, 34, 26))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 5, 29, 16, 25, 37))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 6, 20, 13, 27, 52))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 6, 21, 10, 5, 9))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 6, 23, 19, 35, 38))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 6, 26, 1, 1, 28))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 7, 8, 20, 32, 53))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 7, 15, 6, 6, 28))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 7, 16, 22, 34, 51))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 7, 18, 8, 17, 58))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 3, 2, 41, 59))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 3, 6, 33, 55))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 5, 14, 57, 6))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 6, 12, 2, 39))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 6, 18, 5, 44))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 10, 9, 19, 28))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 19, 12, 45, 20))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 22, 9, 2, 32))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 23, 6, 40, 54))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 28, 15, 36, 6))
# ('Amadeus Holy', 2006, datetime.datetime(2005, 8, 30, 14, 27, 53))
# ('Amadeus Holy', 2006, None)
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 6, 18, 15, 42, 52))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 6, 23, 20, 34, 56))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 7, 11, 11, 35, 27))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 7, 15, 7, 21, 3))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 8, 3, 15, 27, 22))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 8, 8, 6, 12, 26))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 8, 8, 9, 41, 44))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 8, 18, 15, 55, 30))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 8, 24, 13, 23, 51))
# ('Amelie Hellfighters', 2006, datetime.datetime(2005, 8, 25, 19, 4, 2))
# ('American Circus', 2006, datetime.datetime(2005, 5, 27, 9, 32, 38))
# ('American Circus', 2006, datetime.datetime(2005, 6, 3, 17, 50, 58))
# ('American Circus', 2006, datetime.datetime(2005, 6, 17, 15, 17, 41))
# ('American Circus', 2006, datetime.datetime(2005, 6, 22, 11, 59, 22))
# ('American Circus', 2006, datetime.datetime(2005, 6, 27, 21, 48, 27))
# ('American Circus', 2006, datetime.datetime(2005, 7, 8, 8, 31, 37))
# ('American Circus', 2006, datetime.datetime(2005, 7, 14, 6, 12, 23))
# ('American Circus', 2006, datetime.datetime(2005, 7, 15, 3, 11, 33))
# ('American Circus', 2006, datetime.datetime(2005, 7, 19, 3, 41, 4))
# ('American Circus', 2006, datetime.datetime(2005, 7, 21, 16, 4, 55))
# ('American Circus', 2006, datetime.datetime(2005, 8, 3, 18, 36, 34))
# ('American Circus', 2006, datetime.datetime(2005, 8, 4, 19, 48, 44))
# ('American Circus', 2006, datetime.datetime(2005, 8, 5, 6, 25, 24))
# ('American Circus', 2006, datetime.datetime(2005, 8, 6, 6, 37, 55))
# ('American Circus', 2006, datetime.datetime(2005, 8, 6, 21, 54, 3))
# ('American Circus', 2006, datetime.datetime(2005, 8, 11, 16, 37, 5))
# ('American Circus', 2006, datetime.datetime(2005, 8, 20, 3, 4, 11))
# ('American Circus', 2006, datetime.datetime(2005, 8, 22, 23, 58, 47))
# ('American Circus', 2006, datetime.datetime(2005, 8, 25, 5, 9, 10))
# ('American Circus', 2006, datetime.datetime(2005, 8, 25, 5, 18, 26))
# ('American Circus', 2006, datetime.datetime(2005, 8, 27, 13, 34, 45))
# ('American Circus', 2006, None)
# ('Amistad Midsummer', 2006, datetime.datetime(2005,

# ('Angels Life', 2006, datetime.datetime(2005, 8, 24, 17, 45, 59))
# ('Angels Life', 2006, datetime.datetime(2005, 8, 25, 8, 54, 51))
# ('Angels Life', 2006, datetime.datetime(2005, 8, 27, 23, 36, 59))
# ('Angels Life', 2006, datetime.datetime(2005, 8, 29, 23, 36, 42))
# ('Angels Life', 2006, datetime.datetime(2005, 8, 30, 11, 49))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 1, 13, 26, 26))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 2, 4, 53, 20))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 4, 20, 23, 44))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 21, 11, 48, 46))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 22, 0, 40, 8))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 26, 23, 8, 48))
# ('Annie Identity', 2006, datetime.datetime(2005, 6, 29, 19, 13, 23))
# ('Annie Identity', 2006, datetime.datetime(2005, 7, 11, 7, 13, 21))
# ('Annie Identity', 2006, datetime.datetime(2005, 7, 11, 14, 8, 28))
# ('Annie Identity', 2006, datetime.datetime(2005, 7, 11, 23, 24, 2))
# ('Annie Identity', 2006, datetime.datetime(2005, 7, 12, 21, 46, 5))
# ('Annie Identity', 2006, datetime.datetime(2005, 7, 13, 2, 3, 56))
# ('Annie Identity', 2006, datetime.datetime(2005, 7, 30, 14, 11, 34))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 3, 22, 49, 23))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 4, 5, 26, 48))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 9, 1, 30, 9))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 10, 15, 50, 10))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 20, 23, 13, 13))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 21, 3, 44, 27))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 23, 7, 49, 13))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 28, 22, 9, 51))
# ('Annie Identity', 2006, datetime.datetime(2005, 8, 29, 19, 10, 48))
# ('Anonymous Human', 2006, datetime.datetime(2005, 6, 17, 12, 12, 14))
# ('Anonymous Human', 2006, datetime.datetime(2005, 6, 25, 2, 11, 31))
# ('Anonymous Human', 2006, datetime.datetime(2005, 7, 11, 10, 41, 30))
# ('Anonymous Human', 2006, datetime.datetime(2005, 7, 11, 22, 43, 17))
# ('Anonymous Human', 2006, datetime.datetime(2005, 7, 16, 16, 30, 50))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 1, 18, 22, 14))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 6, 6, 28, 26))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 6, 6, 50, 39))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 8, 15, 49, 46))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 21, 18, 33, 10))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 24, 19, 36, 15))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 25, 3, 8, 25))
# ('Anonymous Human', 2006, datetime.datetime(2005, 8, 26, 14, 4, 52))
# ('Anthem Luke', 2006, datetime.datetime(2005, 6, 1, 2, 50, 33))
# ('Anthem Luke', 2006, datetime.datetime(2005, 6, 1, 18, 32, 22))
# ('Anthem Luke', 2006, datetime.datetime(2005, 6, 1, 20, 50, 12))
# ('Anthem Luke', 2006, datetime.datetime(2005, 6, 20, 0, 6, 33))
# ('Anthem Luke', 2006, datetime.datetime(2005, 6, 22, 20, 17, 10))
# ('Anthem Luke', 2006, datetime.datetime(2005, 6, 22, 23, 6, 54))
# ('Anthem Luke', 2006, datetime.datetime(2005, 7, 11, 17, 36, 57))
# ('Anthem Luke', 2006, datetime.datetime(2005, 7, 14, 21, 43, 37))
# ('Anthem Luke', 2006, datetime.datetime(2005, 7, 21, 2, 8, 50))
# ('Anthem Luke', 2006, datetime.datetime(2005, 8, 2, 0, 3))
# ('Anthem Luke', 2006, datetime.datetime(2005, 8, 4, 8, 52, 12))
# ('Anthem Luke', 2006, datetime.datetime(2005, 8, 8, 9, 52, 8))
# ('Anthem Luke', 2006, datetime.datetime(2005, 8, 24, 5, 20, 45))
# ('Anthem Luke', 2006, datetime.datetime(2005, 8, 26, 0, 36, 34))
# ('Anthem Luke', 2006, datetime.datetime(2005, 8, 26, 6, 20, 20))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 6, 2, 17, 13, 15))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 6, 2, 19, 17, 43))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 6, 24, 6, 48, 22))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 6, 25, 22, 30, 6))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 7, 10, 0, 6, 37))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 7, 17, 17, 59, 3))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 8, 2, 5, 18, 36))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 8, 5, 11, 11, 19))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 8, 23, 2, 32, 25))
# ('Antitrust Tomatoes', 2006, datetime.datetime(2005, 8, 24, 20, 55, 21))
# ('Anything Savannah', 2006, datetime.datetime(2005, 5, 28, 7, 10, 25))
# ('Anything Savannah', 2006, datetime.datetime(2005, 6, 22, 15, 26, 24))
# ('Anything Savannah', 2006, datetime.datetime(2005, 6, 24, 3, 12, 7))
# ('Anything Savannah', 2006, datetime.datetime(2005, 7, 9, 22, 33, 24))
# ('Anything Savannah', 2006, datetime.datetime(2005, 7, 15, 17, 48, 24))
# ('Anything Savannah', 2006, datetime.datetime(2005, 8, 3, 7, 18, 42))
# ('Anything Savannah', 2006, datetime.datetime(2005, 8, 9, 9, 53, 21))
# ('Anything Savannah', 2006, datetime.datetime(2005, 8, 22, 19, 18, 35))
# ('Anything Savannah', 2006, datetime.datetime(2005, 8, 31, 5, 43, 12))
# ('Apache Divine', 2006, datetime.datetime(2005, 5, 26, 1, 1, 46))
# ('Apache Divine', 2006, datetime.datetime(2005, 6, 1, 11, 20, 15))
# ('Apache Divine', 2006, datetime.datetime(2005, 6, 7, 18, 9, 24))
# ('Apache Divine', 2006, datetime.datetime(2005, 6, 19, 0, 57, 45))
# ('Apache Divine', 2006, datetime.datetime(2005, 6, 19, 15, 34, 45))
# ('Apache Divine', 2006, datetime.datetime(2005, 6, 20, 9, 18, 23))
# ('Apache Divine', 2006, datetime.datetime(2005, 6, 23, 6, 33, 8))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 7, 22, 39, 48))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 8, 20, 34, 19))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 11, 2, 20, 32))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 12, 4, 43, 24))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 13, 21, 36, 38))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 14, 19, 48, 16))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 15, 16, 9, 24))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 16, 5, 30, 12))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 31, 1, 13, 54))
# ('Apache Divine', 2006, datetime.datetime(2005, 7, 31, 5, 27, 20))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 4, 5, 12, 32))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 4, 14, 30, 32))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 5, 5, 29, 23))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 5, 23, 52, 18))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 9, 9, 18, 51))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 10, 9, 49, 3))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 18, 19, 34, 12))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 22, 22, 19, 38))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 24, 22, 27, 44))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 25, 21, 56, 57))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 28, 2, 16, 15))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 29, 9, 28, 42))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 29, 11, 5, 26))
# ('Apache Divine', 2006, datetime.datetime(2005, 8, 29, 23, 3, 18))
# ('Apocalypse Flamingos', 2006, datetime.datetime(2005, 6, 27, 15, 50))
# ('Apocalypse Flamingos', 2006, datetime.datetime(2005, 7, 11, 23, 10, 54))
# ('Apocalypse Flamingos', 2006, datetime.datetime(2005, 7, 28, 1, 6, 38))
# ('Apocalypse Flamingos', 2006, datetime.datetime(2005, 8, 5, 4, 55, 54))
# ('Apocalypse Flamingos', 2006, datetime.datetime(2005, 8, 26, 21, 36, 18))
# ('Apocalypse Flamingos', 2006, datetime.datetime(2005, 8, 28, 22, 17, 48))
# ('Arabia Dogma', 2006, datetime.datetime(2005, 6, 3, 10, 42, 22))
# ('Arabia Dogma', 2006, datetime.datetime(2005, 6, 18, 1, 49, 56))
# ('Arabia Dogma', 2006, datetime.datetime(2005,
# ('Attraction Newton', 2006, datetime.datetime(2005, 6, 27, 11, 56, 31))
# ('Attraction Newton', 2006, datetime.datetime(2005, 6, 28, 3, 30, 28))
# ('Attraction Newton', 2006, datetime.datetime(2005, 7, 10, 5, 48, 21))
# ('Attraction Newton', 2006, datetime.datetime(2005, 7, 13, 2, 56, 22))
# ('Attraction Newton', 2006, datetime.datetime(2005, 7, 13, 15, 13, 52))
# ('Attraction Newton', 2006, datetime.datetime(2005, 7, 14, 6, 11, 9))
# ('Attraction Newton', 2006, datetime.datetime(2005, 7, 14, 22, 17, 43))
# ('Attraction Newton', 2006, datetime.datetime(2005, 7, 16, 1, 12, 46))
# ('Attraction Newton', 2006, datetime.datetime(2005, 8, 3, 11, 36, 9))
# ('Attraction Newton', 2006, datetime.datetime(2005, 8, 3, 16, 32, 48))
# ...
# ('Wonderland Christmas', 2006, datetime.datetime(2005, 8, 29, 10, 48, 42))
# ('Wonderland Christmas', 2006, datetime.datetime(2005, 8, 31, 12, 45, 54))
# ('Wonka Sea', 2006, datetime.datetime(2005, 6, 21, 4, 58, 47))
# ('Wonka Sea', 2006, datetime.datetime(2005, 6, 23, 14, 3, 29))
# ('Wonka Sea', 2006, datetime.datetime(2005, 7, 7, 8, 7, 35))
# ('Wonka Sea', 2006, datetime.datetime(2005, 7, 12, 20, 57, 28))
# ('Wonka Sea', 2006, datetime.datetime(2005, 7, 13, 5, 17, 43))
# ('Wonka Sea', 2006, datetime.datetime(2005, 7, 14, 5, 12, 33))
# ('Wonka Sea', 2006, datetime.datetime(2005, 7, 31, 10, 15, 1))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 3, 14, 16, 36))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 4, 2, 53, 15))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 5, 1, 35, 4))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 5, 2, 34, 37))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 10, 15, 52, 41))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 22, 16, 49, 28))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 22, 17, 44, 50))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 25, 17, 25, 1))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 25, 19, 36, 15))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 27, 6, 33, 49))
# ('Wonka Sea', 2006, datetime.datetime(2005, 8, 31, 11, 20, 33))
# ('Words Hunter', 2006, datetime.datetime(2005, 6, 2, 6, 39))
# ('Words Hunter', 2006, datetime.datetime(2005, 6, 6, 11, 31, 32))
# ('Words Hunter', 2006, datetime.datetime(2005, 6, 19, 16, 5, 32))
# ('Words Hunter', 2006, datetime.datetime(2005, 6, 26, 6, 59, 27))
# ('Words Hunter', 2006, datetime.datetime(2005, 7, 11, 1, 18, 21))
# ('Words Hunter', 2006, datetime.datetime(2005, 7, 13, 0, 51, 23))
# ('Words Hunter', 2006, datetime.datetime(2005, 7, 14, 1, 27, 9))
# ('Words Hunter', 2006, datetime.datetime(2005, 7, 15, 18, 13, 23))
# ('Words Hunter', 2006, datetime.datetime(2005, 7, 30, 5, 3, 30))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 5, 3, 55, 11))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 6, 6, 4, 40))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 8, 1, 51, 57))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 23, 19, 49, 1))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 24, 18, 7, 48))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 24, 20, 9, 33))
# ('Words Hunter', 2006, datetime.datetime(2005, 8, 29, 23, 39, 36))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 6, 25, 12, 36, 5))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 6, 26, 17, 54, 32))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 7, 13, 15, 12, 9))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 7, 13, 19, 41, 1))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 7, 15, 20, 6, 12))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 7, 31, 10, 24, 14))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 2, 9, 52, 28))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 6, 16, 15, 59))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 7, 10, 39, 24))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 10, 0, 0, 41))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 23, 0, 49, 37))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 23, 14, 44, 33))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 25, 19, 46, 11))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 29, 1, 38, 26))
# ('Worker Tarzan', 2006, datetime.datetime(2005, 8, 30, 7, 32, 22))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 3, 10, 8, 41))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 5, 22, 47, 17))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 18, 5, 43, 30))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 21, 7, 53, 52))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 21, 8, 1, 18))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 26, 11, 55, 35))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 6, 26, 17, 18, 45))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 7, 8, 10, 44, 31))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 7, 10, 15, 39, 14))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 7, 12, 12, 11, 7))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 7, 14, 20, 45, 45))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 7, 18, 16, 56, 4))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 7, 19, 5, 11, 24))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 1, 16, 20, 31))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 4, 4, 56, 27))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 5, 3, 26, 26))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 5, 15, 56, 54))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 7, 23, 3, 58))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 8, 3, 53, 41))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 22, 2, 47, 32))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 24, 9, 9, 9))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 24, 14, 55, 47))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 28, 5, 12, 58))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 29, 21, 35, 1))
# ('Working Microcosmos', 2006, datetime.datetime(2005, 8, 30, 19, 4, 49))
# ('World Leathernecks', 2006, datetime.datetime(2005, 6, 16, 18, 24, 37))
# ('World Leathernecks', 2006, datetime.datetime(2005, 6, 25, 4, 4, 39))
# ('World Leathernecks', 2006, datetime.datetime(2005, 7, 8, 1, 21, 8))
# ('World Leathernecks', 2006, datetime.datetime(2005, 7, 18, 23, 5, 29))
# ('World Leathernecks', 2006, datetime.datetime(2005, 8, 4, 2, 17, 26))
# ('World Leathernecks', 2006, datetime.datetime(2005, 8, 4, 10, 0, 49))
# ('World Leathernecks', 2006, datetime.datetime(2005, 8, 27, 13, 56, 1))
# ('World Leathernecks', 2006, None)
# ('Worst Banger', 2006, datetime.datetime(2005, 6, 6, 4, 51, 31))
# ('Worst Banger', 2006, datetime.datetime(2005, 6, 24, 8, 5, 15))
# ('Worst Banger', 2006, datetime.datetime(2005, 6, 24, 17, 43, 52))
# ('Worst Banger', 2006, datetime.datetime(2005, 7, 10, 3, 23, 45))
# ('Worst Banger', 2006, datetime.datetime(2005, 7, 12, 22, 26, 29))
# ('Worst Banger', 2006, datetime.datetime(2005, 7, 16, 22, 24, 3))
# ('Worst Banger', 2006, datetime.datetime(2005, 7, 29, 15, 13, 13))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 1, 23, 51, 54))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 2, 14, 46, 18))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 4, 16, 25, 45))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 8, 22, 29, 50))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 23, 8, 54, 27))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 24, 0, 46, 26))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 26, 19, 46, 37))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 28, 0, 28, 21))
# ('Worst Banger', 2006, datetime.datetime(2005, 8, 30, 0, 44, 52))
# ('Wrath Mile', 2006, datetime.datetime(2005, 6, 5, 12, 10, 41))
# ('Wrath Mile', 2006, datetime.datetime(2005, 6, 20, 7, 59, 51))
# ('Wrath Mile', 2006, datetime.datetime(2005, 6, 26, 14, 31, 22))
# ('Wrath Mile', 2006, datetime.datetime(2005, 7, 9, 5, 47, 54))
# ('Wrath Mile', 2006, datetime.datetime(2005, 7, 13, 10, 36, 22))
# ('Wrath Mile', 2006, datetime.datetime(2005, 7, 16, 8, 6, 31))
# ('Wrath Mile', 2006, datetime.datetime(2005, 7, 29, 23, 35, 1))
# ('Youth Kick', 2006, datetime.datetime(2005, 8, 3, 5, 4, 15))
# ('Youth Kick', 2006, datetime.datetime(2005, 8, 5, 10, 56, 37))
# ('Youth Kick', 2006, datetime.datetime(2005, 8, 24, 16, 43, 36))
# ('Youth Kick', 2006, datetime.datetime(2005, 8, 25, 5, 51, 19))
# ('Zhivago Core', 2006, datetime.datetime(2005, 6, 7, 0, 49, 20))
# ('Zhivago Core', 2006, datetime.datetime(2005, 6, 21, 0, 19, 20))
# ('Zhivago Core', 2006, datetime.datetime(2005, 6, 26, 9, 48, 54))
# ('Zhivago Core', 2006, datetime.datetime(2005, 7, 12, 9, 47, 57))
# ('Zhivago Core', 2006, datetime.datetime(2005, 7, 16, 3, 43, 2))
# ('Zhivago Core', 2006, datetime.datetime(2005, 7, 31, 19, 48, 55))
# ('Zhivago Core', 2006, datetime.datetime(2005, 8, 10, 21, 58, 4))
# ('Zhivago Core', 2006, datetime.datetime(2005, 8, 26, 15, 31, 48))
# ('Zhivago Core', 2006, None)
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 6, 4, 6, 22, 30))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 6, 20, 20, 11, 9))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 6, 24, 9, 9, 36))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 7, 10, 2, 49, 54))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 7, 14, 12, 8, 27))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 7, 14, 13, 27, 24))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 7, 19, 10, 12, 41))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 7, 29, 1, 5, 4))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 3, 6, 25, 43))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 5, 9, 7, 8))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 7, 17, 37, 43))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 10, 0, 23, 23))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 24, 15, 22, 27))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 25, 6, 8, 24))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 27, 14, 19, 43))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 29, 0, 18, 56))
# ('Zoolander Fiction', 2006, datetime.datetime(2005, 8, 31, 21, 37, 5))
# ('Zorro Ark', 2006, datetime.datetime(2005, 5, 29, 8, 33, 46))
# ('Zorro Ark', 2006, datetime.datetime(2005, 5, 31, 8, 29, 3))
# ('Zorro Ark', 2006, datetime.datetime(2005, 6, 1, 11, 15, 17))
# ('Zorro Ark', 2006, datetime.datetime(2005, 6, 17, 1, 2, 32))
# ('Zorro Ark', 2006, datetime.datetime(2005, 6, 20, 19, 33, 51))
# ('Zorro Ark', 2006, datetime.datetime(2005, 6, 21, 21, 35, 21))
# ('Zorro Ark', 2006, datetime.datetime(2005, 6, 23, 4, 42, 59))
# ('Zorro Ark', 2006, datetime.datetime(2005, 6, 24, 16, 36))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 8, 15, 10, 45))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 14, 13, 2, 9))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 15, 9, 30, 22))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 16, 7, 28, 2))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 16, 21, 36, 33))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 17, 21, 1, 54))
# ('Zorro Ark', 2006, datetime.datetime(2005, 7, 20, 9, 35, 47))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 1, 5, 7, 21))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 3, 14, 29, 11))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 5, 10, 38, 55))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 6, 3, 23, 24))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 6, 4, 52, 25))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 6, 5, 2, 48))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 8, 22, 3, 5))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 9, 8, 18, 35))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 21, 0, 14, 32))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 21, 13, 28, 51))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 22, 14, 30, 53))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 22, 18, 53, 42))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 24, 4, 16, 51))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 25, 1, 51, 28))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 27, 17, 48, 24))
# ('Zorro Ark', 2006, datetime.datetime(2005, 8, 31, 21, 49, 1))

# %%
# EXERCISE 4
# How many rentals were in between 2005-07-01 and 2005-08-01?
from sqlalchemy import and_
import datetime

mapper_stmt4 = select( [dic_table['rental']]).\
                      where(and_(dic_table['rental'].columns.rental_date > datetime.datetime(2006, 7, 1),\
                                 dic_table['rental'].columns.rental_date < datetime.datetime(2006, 8, 1)))

result4 = db.execute(mapper_stmt4).fetchall()
result4_length = len(result4)

# %%
print(result4_length)
# 0 results
# Out:
# 0

# %%
# EXERCISE 5
# How many rentals were in between 2010-01-01 and 2011-02-01?

mapper_stmt5 = select([dic_table['rental']]).\
                       where(and_(dic_table['rental'].columns.rental_date > datetime.datetime(2010, 1, 1),\
                                  dic_table['rental'].columns.rental_date < datetime.datetime(2011, 2, 1) ) )

result5 = db.execute(mapper_stmt5).fetchall()
result5_length = len(result5)

# %%
print(result5_length)
# 0 results
# Out:
# 0

# %%
# EXERCISE 6
# Find the biggest payment in the rental.

mapper_stmt6 = 'SELECT max(payment.amount) from payment'
result6 = db.execute(mapper_stmt6).fetchall()

# %%
print(result6)
# 1 result
# Out:
# [(Decimal('11.99'),)]

# %%
# EXERCISE 7
# Find all customers from Poland, Nigeria or Bangladesh.

mapper_stmt7 = " SELECT customer.first_name, customer.last_name, country.country from customer \
                INNER JOIN address on address.address_id = customer.address_id \
                INNER JOIN city on city.city_id = address.city_id \
                INNER JOIN country on country.country_id = city.country_id \
            WHERE (country.country = 'Poland' or country.country = 'Nigeria' or country.country = 'Bangladesh') \
            GROUP BY customer.first_name, customer.last_name, country.country "

result7 = db.execute(mapper_stmt7).fetchall()

# %%
for i in result7:
    print(i)
# 24 results
# Out:
# ('Bertha', 'Ferguson', 'Nigeria')
# ('Brian', 'Wyman', 'Poland')
# ('Carol', 'Garcia', 'Nigeria')
# ('Constance', 'Reid', 'Nigeria')
# ('Elsie', 'Kelley', 'Nigeria')
# ('Frank', 'Waggoner', 'Bangladesh')
# ('Gladys', 'Hamilton', 'Nigeria')
# ('Jimmie', 'Eggleston', 'Poland')
# ('Jo', 'Fowler', 'Nigeria')
# ('Johnnie', 'Chisholm', 'Poland')
# ('Leah', 'Curtis', 'Poland')
# ('Marilyn', 'Ross', 'Nigeria')
# ('Marjorie', 'Tucker', 'Poland')
# ('Michelle', 'Clark', 'Bangladesh')
# ('Olga', 'Jimenez', 'Nigeria')
# ('Rodney', 'Moeller', 'Nigeria')
# ('Ruben', 'Geary', 'Poland')
# ('Russell', 'Brinson', 'Poland')
# ('Sidney', 'Burleson', 'Poland')
# ('Sonia', 'Gregory', 'Nigeria')
# ('Stephen', 'Qualls', 'Bangladesh')
# ('Tracey', 'Barrett', 'Nigeria')
# ('Velma', 'Lucas', 'Nigeria')
# ('Wallace', 'Slone', 'Nigeria')

# %%
# EXERCISE 8
# Where staff memebers live?

mapper_stmt8 = " SELECT staff.first_name AS name, staff.last_name AS surname, address.address AS street, \
                city.city AS cityName, country.country AS countryName FROM staff \
                    INNER JOIN address ON address.address_id = staff.address_id \
                    INNER JOIN city ON city.city_id = address.city_id \
                    INNER JOIN country ON country.country_id = city.country_id \
                GROUP BY name, surname, street, cityName, countryName "

result8 = db.execute(mapper_stmt8).fetchall()

# %%
for i in result8:
    print(i)
# 2 results
# Out:
# ('Jon', 'Stephens', '1411 Lillydale Drive', 'Woodridge', 'Australia')
# ('Mike', 'Hillyer', '23 Workhaven Lane', 'Lethbridge', 'Canada')

# %%
# EXERCISE 9
# How many staff members live in Argentina or Spain?

mapper_stmt9 = " SELECT COUNT (*) FROM \
                ( \
                    SELECT staff.first_name as staffName, staff.last_name as surname, address.address as street, \
                    city.city as cityName, country.country as countryName FROM staff \
                        INNER JOIN address ON address.address_id = staff.address_id \
                        INNER JOIN city ON city.city_id = address.city_id \
                        INNER JOIN country ON country.country_id = city.country_id \
                    GROUP BY staffName, surname, street, cityName, countryName \
                ) AS temp_table \
                WHERE countryName = 'Argentina' OR countryName = 'Spain' "

result9 = db.execute(mapper_stmt9).fetchall()

# %%
for i in result9:
    print(i)
# 0 results
# Out:
# (0,)

# %%
# EXERCISE 10
# Which categories of the films were rented by clients?

mapper_stmt10 = " SELECT distinct category.name FROM category \
                    INNER JOIN film_category ON category.category_id = film_category.category_id \
                    INNER JOIN film ON film_category.film_id = film.film_id \
                    INNER JOIN inventory ON film.film_id = inventory.film_id \
                    INNER JOIN rental ON rental.inventory_id = inventory.inventory_id \
                ORDER BY category.name "

result10 = db.execute(mapper_stmt10).fetchall()

# %%
for i in result10:
    print(i)
# 16 results
# Out:
# ('Action',)
# ('Animation',)
# ('Children',)
# ('Classics',)
# ('Comedy',)
# ('Documentary',)
# ('Drama',)
# ('Family',)
# ('Foreign',)
# ('Games',)
# ('Horror',)
# ('Music',)
# ('New',)
# ('Sci-Fi',)
# ('Sports',)
# ('Travel',)

# %%
# EXERCISE 11
# Find all categories of films rented in America.

mapper_stmt11 = " SELECT distinct category.name FROM category \
                    INNER JOIN film_category ON category.category_id = film_category.category_id \
                    INNER JOIN film ON film_category.film_id = film.film_id \
                    INNER JOIN inventory ON film.film_id = inventory.film_id \
                    INNER JOIN rental ON rental.inventory_id = inventory.inventory_id \
                    INNER JOIN customer ON rental.customer_id = customer.customer_id \
                    INNER JOIN address ON customer.address_id = address.address_id \
                    INNER JOIN city ON address.city_id = city.city_id \
                    INNER JOIN country ON city.country_id = country.country_id \
                WHERE country.country = 'America' \
                ORDER BY category.name "

result11 = db.execute(mapper_stmt11).fetchall()
length_task11 = len(result11)

# %%
print(length_task11)
# 0 results
# Out:
# 0

# %%
# EXERCISE 12
# Find all title of films where one of these actors played: ,,Olympia Pfeiffer", ,,Julia Zellweger" or ,,Ellen Presley"

mapper_stmt12 = " SELECT film.title, actor.first_name, actor.last_name FROM film \
                    INNER JOIN film_actor ON film_actor.film_id = film.film_id \
                    INNER JOIN actor ON actor.actor_id = film_actor.actor_id \
                WHERE (actor.first_name = 'Olympia' AND actor.last_name = 'Pfeiffer') OR \
                      (actor.first_name = 'Julia' AND actor.last_name = 'Zellweger') OR \
                      (actor.first_name = 'Ellen' AND actor.last_name = 'Presley') \
                ORDER BY film.title "

result12 = db.execute(mapper_stmt12).fetchall()
result12_length = len(result12)

# %%
print(result12_length)
# 69 results
# Out:
# 69
