# %%
# ADVANCED DATABASES - LAB #3
# Creating database in SQLAlchemy

# Data set: (len(your_name) + len(your_surname))% 6 = (6+4)%6
# Data set: 4 ,,superbowl-history-1967-2020"

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

engine = create_engine(db_string)

# Run process of mapping existing tables in a database to class and give us tools to declare new tables schema.
Base = declarative_base()

# %%
#Add tools of mapping variablis types from databse to Python => declare new table schema

from sqlalchemy import Column, Integer, String, Date

# %%
# TEAM (id_team, name)
# MATCH (id_match, date, sb)
# MATCH'S RESULT (id_match, id_stadium, winner (id_team), winner points, loser(id_team), loser points, mvp)
# STADIUM (id_stadium, stadium name, city, state)

# %%
# table "TEAM" initialization

class Team(Base):
    __tablename__ = 'teams'
    id   = Column(Integer, primary_key=True)
    name = Column(String(50))

    def __repr__(self):
        return "<teams(id='{0}', name={1})>".format(self.id, self.name)

# %%
# table "MATCH" initialization

class Match(Base):
    __tablename__ = 'matches'
    id   = Column(Integer, primary_key=True)
    date = Column(Date)
    sb   = Column(String(50))

    def __repr__(self):
        return "<matches(id='{0}', date={1}, sb={2})>".format(
            self.id, self.date, self.sb)

# %%
# table "MATCH RESULT" initialization

class MatchResult(Base):
    __tablename__ = 'match_results'
    id            = Column(Integer, primary_key=True)
    id_stadium    = Column(Integer)
    winner        = Column(Integer)
    winner_points = Column(Integer)
    loser         = Column(Integer)
    loser_points  = Column(Integer)
    mvp           = Column(String(50))

    def __repr__(self):
        return "<match_results(id='{0}', id_stadium={1}, winner={2}, winner_points={3}, loser={4}, loser_points={5}, mvp={6})>".format(
            self.id, self.id_stadium, self.winner, self.winner_points, self.loser, self.loser_points, self.mvp)

# %%
# table "STADIUM" initialization

class Stadium(Base):
    __tablename__ = 'stadiums'
    id    = Column(Integer, primary_key=True)
    name  = Column(String(50))
    city  = Column(String(50))
    state = Column(String(50))

    def __repr__(self):
        return "<matches(id='{0}', name={1}, city={2}, state={3})>".format(
            self.id, self.name, self.city, self.state)

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
session = Session()

# Add data to database
team1  = Team(name = 'Atlanta Falcons')

session.add(team1)

session.commit()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# UndefinedTable: relation "teams" does not exist
# LINE 1: INSERT INTO teams (name) VALUES ('Atlanta Falcons') RETURNIN...
#                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Session establishes all conversations with the database.
# To create this mechanizm we use:

from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
session = Session()

# Add data to database
team1  = Team(name = 'Atlanta Falcons')
team2  = Team(name = 'Baltimore Colts')
team3  = Team(name = 'Baltimore Ravens')
team4  = Team(name = 'Buffalo Bills')
team5  = Team(name = 'Carolina Panthers')

team6  = Team(name = 'Chicago Bears')
team7  = Team(name = 'Cincinnati Bengals')
team8  = Team(name = 'Dallas Cowboys')
team9  = Team(name = 'Denver Broncos')
team10  = Team(name = 'Green Bay Packers')

team11  = Team(name = 'Indianapolis Colts')
team12  = Team(name = 'Kansas City Chiefs')
team13  = Team(name = 'Los Angeles Raiders')
team14  = Team(name = 'Los Angeles Rams')
team15  = Team(name = 'Miami Dolphins')

team16  = Team(name = 'Minnesota Vikings')
team17  = Team(name = 'New England Patriots')
team18  = Team(name = 'New Orleans Saints')
team19  = Team(name = 'New York Giants')
team20  = Team(name = 'New York Jets')

team21  = Team(name = 'Oakland Raiders')
team22  = Team(name = 'Philadelphia Eagles')
team23  = Team(name = 'Pittsburgh Steelers')
team24  = Team(name = 'San Diego Chargers')
team25  = Team(name = 'San Francisco 49ers')

team26  = Team(name = 'Seattle Seahawks')
team27  = Team(name = 'St. Louis Rams')
team28  = Team(name = 'Tampa Bay Buccaneers')
team29  = Team(name = 'Tennessee Titans')
team30  = Team(name = 'Washington Redskins')

session.add(team1)
session.add(team2)
session.add(team3)
session.add(team4)
session.add(team5)
session.add(team6)
session.add(team7)
session.add(team8)
session.add(team9)
session.add(team10)
session.add(team11)
session.add(team12)
session.add(team13)
session.add(team14)
session.add(team15)
session.add(team16)
session.add(team17)
session.add(team18)
session.add(team19)
session.add(team20)
session.add(team21)
session.add(team22)
session.add(team23)
session.add(team24)
session.add(team25)
session.add(team26)
session.add(team27)
session.add(team28)
session.add(team29)
session.add(team30)

session.commit()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# UndefinedTable: relation "teams" does not exist
# LINE 1: INSERT INTO teams (name) VALUES ('Atlanta Falcons') RETURNIN...
#                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Session establishes all conversations with the database.
# To create this mechanizm we use:

from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)
session = Session()

# Add data to database
match1  = Match(date = 'Feb 2 2020', sb = 'LIV (54)')
match2  = Match(date = 'Feb 3 2019', sb = 'LIII (53)')
match3  = Match(date = 'Feb 4 2018', sb = 'LII (52)')
match4  = Match(date = 'Feb 5 2017', sb = 'LI (51)')
match5  = Match(date = 'Feb 7 2016', sb = '50')

match6  = Match(date = 'Feb 1 2015', sb = 'XLIX (49)')
match7  = Match(date = 'Feb 2 2014', sb = 'XLVIII (48)')
match8  = Match(date = 'Feb 3 2013', sb = 'XLVII (47)')
match9  = Match(date = 'Feb 5 2012', sb = 'XLVI (46)')
match10  = Match(date = 'Feb 6 2011', sb = 'XLV (45)')

match11  = Match(date = 'Feb 7 2010', sb = 'XLIV (44)')
match12  = Match(date = 'Feb 1 2009', sb = 'XLIII (43)')
match13  = Match(date = 'Feb 3 2008', sb = 'XLII (42)')
match14  = Match(date = 'Feb 4 2007', sb = 'XLI (41)')
match15  = Match(date = 'Feb 5 2006', sb = 'XL (40)')

match16  = Match(date = 'Feb 6 2005', sb = 'XXXIX (39)')
match17  = Match(date = 'Feb 1 2004', sb = 'XXXVIII (38)')
match18  = Match(date = 'Jan 26 2003', sb = 'XXXVII (37)')
match19  = Match(date = 'Feb 3 2002', sb = 'XXXVI (36)')
match20  = Match(date = 'Jan 28 2001', sb = 'XXXV (35)')

match21  = Match(date = 'Jan 30 2000', sb = 'XXXIV (34)')
match22  = Match(date = 'Jan 31 1999', sb = 'XXXIII (33)')
match23  = Match(date = 'Jan 25 1998', sb = 'XXXII (32)')
match24  = Match(date = 'Jan 26 1997', sb = 'XXXI (31)')
match25  = Match(date = 'Jan 28 1996', sb = 'XXX (30)')

match26  = Match(date = 'Jan 29 1995', sb = 'XXIX (29)')
match27  = Match(date = 'Jan 30 1994', sb = 'XXVIII (28)')
match28  = Match(date = 'Jan 31 1993', sb = 'XXVII (27)')
match29  = Match(date = 'Jan 26 1992', sb = 'XXVI (26)')
match30  = Match(date = 'Jan 27 1991', sb = 'XXV (25)')

match31  = Match(date = 'Jan 28 1990', sb = 'XXIV (24)')
match32  = Match(date = 'Jan 22 1989', sb = 'XXIII (23)')
match33  = Match(date = 'Jan 31 1988', sb = 'XXII (22)')
match34  = Match(date = 'Jan 25 1987', sb = 'XXI (21)')
match35  = Match(date = 'Jan 26 1986', sb = 'XX (20)')

match36  = Match(date = 'Jan 20 1985', sb = 'XIX (19)')
match37  = Match(date = 'Jan 22 1984', sb = 'XVIII (18)')
match38  = Match(date = 'Jan 30 1983', sb = 'XVII (17)')
match39  = Match(date = 'Jan 24 1982', sb = 'XVI (16)')
match40  = Match(date = 'Jan 25 1981', sb = 'XV (15)')

match41  = Match(date = 'Jan 20 1980', sb = 'XIV (14)')
match42  = Match(date = 'Jan 21 1979', sb = 'XIII (13)')
match43  = Match(date = 'Jan 15 1978', sb = 'XII (12)')
match44  = Match(date = 'Jan 9 1977', sb = 'XI (11)')
match45  = Match(date = 'Jan 18 1976', sb = 'X (10)')

match46  = Match(date = 'Jan 12 1975', sb = 'IX (9)')
match47  = Match(date = 'Jan 13 1974', sb = 'VIII (8)')
match48  = Match(date = 'Jan 14 1973', sb = 'VII (7)')
match49  = Match(date = 'Jan 16 1972', sb = 'VI (6)')
match50  = Match(date = 'Jan 17 1971', sb = 'V (5)')

match51  = Match(date = 'Jan 11 1970', sb = 'IV (4)')
match52  = Match(date = 'Jan 12 1969', sb = 'III (3)')
match53  = Match(date = 'Jan 14 1968', sb = 'II (2)')
match54  = Match(date = 'Jan 15 1967', sb = 'I (1)')

session.add(match1)
session.add(match2)
session.add(match3)
session.add(match4)
session.add(match5)
session.add(match6)
session.add(match7)
session.add(match8)
session.add(match9)
session.add(match10)
session.add(match11)
session.add(match12)
session.add(match13)
session.add(match14)
session.add(match15)
session.add(match16)
session.add(match17)
session.add(match18)
session.add(match19)
session.add(match20)
session.add(match21)
session.add(match22)
session.add(match23)
session.add(match24)
session.add(match25)
session.add(match26)
session.add(match27)
session.add(match28)
session.add(match29)
session.add(match30)
session.add(match31)
session.add(match32)
session.add(match33)
session.add(match34)
session.add(match35)
session.add(match36)
session.add(match37)
session.add(match38)
session.add(match39)
session.add(match40)
session.add(match41)
session.add(match42)
session.add(match43)
session.add(match44)
session.add(match45)
session.add(match46)
session.add(match47)
session.add(match48)
session.add(match49)
session.add(match50)
session.add(match51)
session.add(match52)
session.add(match53)
session.add(match54)

session.commit()
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# UndefinedTable: relation "matches" does not exist
# LINE 1: INSERT INTO matches (date, sb) VALUES ('Feb 2 2020', 'LIV (5...
#                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Add data to database
stadium1  = Stadium(name = 'Alltel Stadium', city = 'Jacksonville', state = 'Florida')
stadium2  = Stadium(name = 'Cowboys Stadium', city = 'Arlington', state = 'Texas')
stadium3  = Stadium(name = 'Dolphin Stadium', city = 'Miami Gardens', state = 'Florida')
stadium4  = Stadium(name = 'Ford Field', city = 'Detroit', state = 'Michigan')
stadium5  = Stadium(name = 'Georgia Dome', city = 'Atlanta', state = 'Georgia')

stadium6  = Stadium(name = 'Hard Rock Stadium', city = 'Miami Gardens', state = 'Florida')
stadium7  = Stadium(name = 'Jack Murphy Stadium', city = 'San Diego', state = 'California')
stadium8  = Stadium(name = 'Joe Robbie Stadium', city = 'Miami Gardens', state = 'Florida')
stadium9  = Stadium(name = 'Levi\'s Stadium', city = 'Santa Clara', state = 'California')
stadium10  = Stadium(name = 'Louisiana Superdome', city = 'New Orleans', state = 'Louisiana')

stadium11  = Stadium(name = 'Lucas Oil Stadium', city = 'Indianapolis', state = 'Indiana')
stadium12  = Stadium(name = 'Memorial Coliseum', city = 'Los Angeles', state = 'California')
stadium13  = Stadium(name = 'Mercedes-Benz Stadium', city = 'Atlanta', state = 'Georgia')
stadium14  = Stadium(name = 'Mercedes-Benz Superdome', city = 'New Orleans', state = 'Louisiana')
stadium15  = Stadium(name = 'MetLife Stadium', city = 'East Rutherford', state = 'New Jersey')

stadium16  = Stadium(name = 'Metrodome', city = 'Minneapolis', state = 'Minnesota')
stadium17  = Stadium(name = 'NRG Stadium', city = 'Houston', state = 'Texas')
stadium18  = Stadium(name = 'Orange Bowl', city = 'Miami', state = 'Florida')
stadium19  = Stadium(name = 'Pontiac Silverdome', city = 'Pontiac', state = 'Michigan')
stadium20  = Stadium(name = 'Pro Player Stadium', city = 'Miami Gardens', state = 'Florida')

stadium21  = Stadium(name = 'Qualcomm Stadium', city = 'San Diego', state = 'California')
stadium22  = Stadium(name = 'Raymond James Stadium', city = 'Tampa', state = 'Florida')
stadium23  = Stadium(name = 'Reliant Stadium', city = 'Houston', state = 'Texas')
stadium24  = Stadium(name = 'Rice Stadium', city = 'Houston', state = 'Texas')
stadium25  = Stadium(name = 'Rose Bowl', city = 'Pasadena', state = 'California')

stadium26  = Stadium(name = 'Stanford Stadium', city = 'Palo Alto', state = 'California')
stadium27  = Stadium(name = 'Sun Devil Stadium', city = 'Tempe', state = 'Arizona')
stadium28  = Stadium(name = 'Sun Life Stadium', city = 'Miami Gardens', state = 'Florida')
stadium29  = Stadium(name = 'Superdome', city = 'New Orleans', state = 'Louisiana')
stadium30  = Stadium(name = 'Tampa Stadium', city = 'Tampa', state = 'Florida')

stadium31  = Stadium(name = 'Tulane Stadium', city = 'New Orleans', state = 'Louisiana')
stadium32  = Stadium(name = 'U.S. Bank Stadium', city = 'Minneapolis', state = 'Minnesota')
stadium33  = Stadium(name = 'University of Phoenix Stadium', city = 'Glendale', state = 'Arizona')

session.add(stadium1)
session.add(stadium2)
session.add(stadium3)
session.add(stadium4)
session.add(stadium5)
session.add(stadium6)
session.add(stadium7)
session.add(stadium8)
session.add(stadium9)
session.add(stadium10)
session.add(stadium11)
session.add(stadium12)
session.add(stadium13)
session.add(stadium14)
session.add(stadium15)
session.add(stadium16)
session.add(stadium17)
session.add(stadium18)
session.add(stadium19)
session.add(stadium20)
session.add(stadium21)
session.add(stadium22)
session.add(stadium23)
session.add(stadium24)
session.add(stadium25)
session.add(stadium26)
session.add(stadium27)
session.add(stadium28)
session.add(stadium29)
session.add(stadium30)
session.add(stadium31)
session.add(stadium32)
session.add(stadium33)

session.commit()
